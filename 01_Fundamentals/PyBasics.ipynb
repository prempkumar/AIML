# %%
import sys
import datetime
import math
import calendar

def pp():
    print("\n----------\n")

"""    
str1 =  "Twinkle, twinkle, little star,"
str2 =  "How I wonder what you are!"
str3 = "Up above the world so high,"
str4 = "Like a diamond in the sky."
print(str1,end='\n')
print('\t'+str2, end='\n')
print('\t\t'+str3, end='\n')
print('\t\t'+str4, end='\n')
print(str1, end='\n')
print('\t'+ str2[:-1], end='\n')
pp()

print("Python version is "+ sys.version, end='\n\n' )
pp()

print(datetime.datetime.now(), end='\n\n' )
pp()

def cir_area(rad):
    return math.pi*rad**2
rd = 1.1
print("Area of circle with radius ", rd , "is : ", end='')
print(cir_area(rd), end='\n\n')
pp()

name = input("Enter your full name (firstname lastname):")
tmp = name.partition(" ")
nm = list(tmp)
print(nm[2] , nm[0], end='\n')
pp()

nmbrs =  input("Enter a few numbers comma separated:")
tmp = nmbrs.split(",")
num_list = list(tmp)
num_tuple = tuple(tmp)
print(num_list,"\n")
print(num_tuple,"\n")
pp()

filenm = input("Enter a file name with extension:")
file_nm = filenm.rsplit(".",1)
print("File's extension is :",file_nm[1])
pp()

tmp = input("Enter the number to iterate and the number of times to iterate (separated by space):")
args = tmp.partition(" ")
nbr = int(args[0])
i, val = 1, 0
while i <= int(args[2]):
    val = val + nbr**i
    i = i+1
    
print("Value of n+nn+nnn.... for the number",args[0],"for",args[2],"iterations is:",val)
pp()

print(calendar.__doc__)
pp()

arg_m = input("Enter the year and month you want to print in yyyy/mm format:")
mnth = arg_m.partition("/")
yr = int(mnth[0])
mon = int(mnth[2])
print(calendar.month(yr,mon,6,3))
pp()

arg = input("Enter two dates in yyyy/mm/dd format separated by space:")
dt_arg = arg.partition(" ")
dt1_arg = dt_arg[0].split("/")
dt2_arg = dt_arg[2].split("/")

yr1, mn1, dy1 = int(dt1_arg[0]),int(dt1_arg[1]),int(dt1_arg[2])
yr2, mn2, dy2 = int(dt2_arg[0]),int(dt2_arg[1]),int(dt2_arg[2])

dt1 = datetime.date(yr1,mn1,dy1)
dt2 = datetime.date(yr2,mn2,dy2)

print(dt1)
print(dt2)

n = dt2 - dt1
print(n.days)
pp()

def testfn():
    \"""a string that you "don't" have to escape
This
is a ....... multi-line
heredoc string --------> example
    \"""
print(testfn.__doc__)
pp()

"""
